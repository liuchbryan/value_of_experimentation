# %% [markdown]
# # Empirical calculation of the risk
#
# This notebook contain the experiment described in Section 5.2 of the paper:
#
# > In Section 4.2 we derived an upper bound on $Var(D)$. To help un-derstand the risk in acquiring E&M capabilities, here we performan empirical calculation on $Var(D)$ to determine how far we arefrom the bound in general.

# %%
from normal_normal_model import var_V, get_prioritisation_value_samples
from util import get_bootstrap_var
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %%
def print_run_setting(count, N, M, mu_X, sigma_X, mu_eps, sigma_1, sigma_2):
    print("Run {}: N = {}, M = {}, mu_X = {}, sigma_X = {}, "
          "mu_epsilon = {}, sigma_1 = {}, sigma_2 = {}"
          .format(count, N, M, np.round(mu_X, 4), 
                  np.round(sigma_X, 4), np.round(mu_eps, 4),
                  np.round(sigma_1, 4), np.round(sigma_2, 4)))

def calculate_var_and_bound(runs=500):
    
    # Constants
    NUM_SAMPLES = 1000
    NUM_BOOTSTRAPS = 500
    run_counter = 0
    
    rel_differences = []
    improvement_bootstrap_vars = []
    improvement_theoretical_var_bounds = []

    for run in range(1, runs+1, 1):
        N = int(10 ** np.random.uniform(1, 3.5))
        M = int(N * np.random.uniform(0.02, 0.6)) + 2
        sigma_X = np.sqrt(np.random.chisquare(3))
        sigma_1 = np.sqrt(np.random.chisquare(3))
        sigma_2 = sigma_1 * np.random.uniform(0.02, 0.9999)
        mu_X = np.random.normal(0, 3)
        mu_epsilon = np.random.normal(0, 3)

        # Reconciling the use of sigmas by numpy
        # and sigma_sqs in the theoretical calculations
        sigma_sq_1 = sigma_1 ** 2
        sigma_sq_2 = sigma_2 ** 2
        sigma_sq_X = sigma_X ** 2

        print_run_setting(run, N, M, mu_X, sigma_X, 
                          mu_epsilon, sigma_1, sigma_2)

        _, _, improvement = (
            get_prioritisation_value_samples(
                NUM_SAMPLES, N, M, mu_X, mu_epsilon, 
                sigma_sq_X, sigma_sq_1, sigma_sq_2, verbose=False)
        )

        improvement_bootstrap_var = (
            np.mean(get_bootstrap_var(improvement, NUM_BOOTSTRAPS))
        )
        improvement_theoretical_var_bound = (
            var_V(sigma_sq_X, sigma_sq_1, N, M) +
            var_V(sigma_sq_X, sigma_sq_2, N, M)
        )
        rel_difference = improvement_bootstrap_var / improvement_theoretical_var_bound
        
        improvement_bootstrap_vars.append(improvement_bootstrap_var)
        improvement_theoretical_var_bounds.append(improvement_theoretical_var_bound)
        rel_differences.append(rel_difference)
        
        print("Run {}: Mean bootstrap Var(D) = {} (High bound: {})"
              .format(run,
                      improvement_bootstrap_var, 
                      improvement_theoretical_var_bound))
    
        if (run % 20 == 0):
            print("Average var to bound ratio so far: {}"
                  .format(np.mean(rel_differences)))
            
    return improvement_bootstrap_vars, improvement_theoretical_var_bounds, rel_differences

# %%
rel_differences = []
improvement_bootstrap_vars = []
improvement_theoretical_var_bounds = []

# Get the bootstrap variance and theoretical high bound in batches of ten
# So that if we require to abort the process we can still access
# some of the results we are interested in.
while True:
    variances, bounds, diffs = calculate_var_and_bound(10)
    improvement_bootstrap_vars = improvement_bootstrap_vars + variances
    improvement_theoretical_var_bounds = improvement_theoretical_var_bounds + bounds
    rel_differences = rel_differences + diffs
# Out:
# Run 1: N = 82, M = 43, mu_X = 1.3005, sigma_X = 1.0937, mu_epsilon = 0.2135, sigma_1 = 2.3993, sigma_2 = 1.1379
# Run 1: Mean bootstrap Var(D) = 0.014040348036837659 (High bound: 0.04981849760386278)
# Run 2: N = 179, M = 16, mu_X = 1.4591, sigma_X = 1.3842, mu_epsilon = 1.0635, sigma_1 = 1.2019, sigma_2 = 0.2203
# Run 2: Mean bootstrap Var(D) = 0.031652725550030604 (High bound: 0.11744265630127124)
# Run 3: N = 1285, M = 632, mu_X = -2.7363, sigma_X = 1.8716, mu_epsilon = -1.7873, sigma_1 = 0.8534, sigma_2 = 0.8289
# Run 3: Mean bootstrap Var(D) = 0.0002941623148218195 (High bound: 0.008089429529369502)
# Run 4: N = 2044, M = 885, mu_X = -3.5366, sigma_X = 1.3999, mu_epsilon = -0.6112, sigma_1 = 0.514, sigma_2 = 0.4149
# Run 4: Mean bootstrap Var(D) = 6.26464134486189e-05 (High bound: 0.002983556589682002)
# Run 5: N = 19, M = 6, mu_X = -3.2579, sigma_X = 1.8719, mu_epsilon = 0.2911, sigma_1 = 2.4697, sigma_2 = 2.3725
# Run 5: Mean bootstrap Var(D) = 0.3582418820352323 (High bound: 0.9459985819516208)
# Run 6: N = 227, M = 78, mu_X = 0.7553, sigma_X = 1.7351, mu_epsilon = -0.0346, sigma_1 = 0.9484, sigma_2 = 0.1961
# Run 6: Mean bootstrap Var(D) = 0.002592032000809898 (High bound: 0.048048396051148176)
# Run 7: N = 33, M = 20, mu_X = -0.2984, sigma_X = 2.4172, mu_epsilon = -1.17, sigma_1 = 2.2793, sigma_2 = 1.8596
# Run 7: Mean bootstrap Var(D) = 0.060536227032789616 (High bound: 0.4852555604672472)
# Run 8: N = 11, M = 5, mu_X = 0.575, sigma_X = 2.2232, mu_epsilon = -3.3538, sigma_1 = 0.7414, sigma_2 = 0.6052
# Run 8: Mean bootstrap Var(D) = 0.023810838027146487 (High bound: 1.1691491816972914)
# Run 9: N = 200, M = 109, mu_X = -3.1736, sigma_X = 2.4711, mu_epsilon = 0.3676, sigma_1 = 1.3222, sigma_2 = 0.4609
# Run 9: Mean bootstrap Var(D) = 0.002450618587260429 (High bound: 0.08297921810546269)
# Run 10: N = 469, M = 142, mu_X = 6.3629, sigma_X = 2.062, mu_epsilon = -0.7496, sigma_1 = 1.7831, sigma_2 = 0.2326
# Run 10: Mean bootstrap Var(D) = 0.004906299248146987 (High bound: 0.03861765878830372)
# Run 1: N = 1488, M = 886, mu_X = 2.0325, sigma_X = 1.538, mu_epsilon = 2.7196, sigma_1 = 2.3985, sigma_2 = 1.0811
# Run 1: Mean bootstrap Var(D) = 0.0008109847569947432 (High bound: 0.0046737512652065445)
# Run 2: N = 172, M = 59, mu_X = -3.4038, sigma_X = 1.3229, mu_epsilon = -1.6108, sigma_1 = 0.6729, sigma_2 = 0.2516
# Run 2: Mean bootstrap Var(D) = 0.0017072249996348203 (High bound: 0.03676270491439316)
# Run 3: N = 73, M = 20, mu_X = 5.8275, sigma_X = 2.6992, mu_epsilon = -2.829, sigma_1 = 0.8964, sigma_2 = 0.8616
# Run 3: Mean bootstrap Var(D) = 0.012901403971860393 (High bound: 0.40235172094763877)
# Run 4: N = 2194, M = 808, mu_X = 5.331, sigma_X = 1.0128, mu_epsilon = -2.7033, sigma_1 = 1.4809, sigma_2 = 0.5113
# Run 4: Mean bootstrap Var(D) = 0.00047900939215311377 (High bound: 0.0019639439820383032)
# Run 5: N = 39, M = 16, mu_X = -2.9939, sigma_X = 1.7454, mu_epsilon = -0.278, sigma_1 = 2.0454, sigma_2 = 0.9799
# Run 5: Mean bootstrap Var(D) = 0.056826769116111855 (High bound: 0.28811213650903833)
# Run 6: N = 532, M = 284, mu_X = 2.2006, sigma_X = 0.5815, mu_epsilon = -3.2297, sigma_1 = 1.7349, sigma_2 = 0.6986
# Run 6: Mean bootstrap Var(D) = 0.0007038928166312907 (High bound: 0.002199265859745728)
# Run 7: N = 1550, M = 738, mu_X = -0.634, sigma_X = 2.512, mu_epsilon = 2.27, sigma_1 = 0.7043, sigma_2 = 0.3077
# Run 7: Mean bootstrap Var(D) = 7.592796545224669e-05 (High bound: 0.011629169819488812)
# Run 8: N = 43, M = 3, mu_X = 6.6707, sigma_X = 1.963, mu_epsilon = -0.4886, sigma_1 = 1.1722, sigma_2 = 0.2058
# Run 8: Mean bootstrap Var(D) = 0.17872184267511912 (High bound: 0.9621757118984071)
# Run 9: N = 11, M = 5, mu_X = -3.0092, sigma_X = 1.0426, mu_epsilon = -1.8982, sigma_1 = 2.415, sigma_2 = 1.3987
# Run 9: Mean bootstrap Var(D) = 0.1455062395477809 (High bound: 0.38487422198541466)
# Run 10: N = 140, M = 77, mu_X = -2.3094, sigma_X = 1.3385, mu_epsilon = -1.7529, sigma_1 = 1.5178, sigma_2 = 0.5704
# Run 10: Mean bootstrap Var(D) = 0.004561938190683043 (High bound: 0.037648000297237916)
# Run 1: N = 37, M = 10, mu_X = -2.2944, sigma_X = 1.2619, mu_epsilon = -0.6166, sigma_1 = 1.2534, sigma_2 = 0.1291
# Run 1: Mean bootstrap Var(D) = 0.034745965028430366 (High bound: 0.19588690473366527)
# Run 2: N = 1441, M = 35, mu_X = -3.6172, sigma_X = 2.0252, mu_epsilon = 3.4426, sigma_1 = 2.9308, sigma_2 = 1.8715
# Run 2: Mean bootstrap Var(D) = 0.1150639131594117 (High bound: 0.15822509891415187)
# Run 3: N = 33, M = 20, mu_X = -4.0319, sigma_X = 1.744, mu_epsilon = -0.5598, sigma_1 = 1.6136, sigma_2 = 1.159
# Run 3: Mean bootstrap Var(D) = 0.024447138907140824 (High bound: 0.2492803412566501)
# Run 4: N = 570, M = 332, mu_X = 4.0486, sigma_X = 0.998, mu_epsilon = 2.3851, sigma_1 = 3.1222, sigma_2 = 0.2413
# Run 4: Mean bootstrap Var(D) = 0.0011567228974055008 (High bound: 0.005162308952756409)
# Run 5: N = 212, M = 113, mu_X = -2.4287, sigma_X = 2.0853, mu_epsilon = -4.2033, sigma_1 = 1.7337, sigma_2 = 0.5371
# Run 5: Mean bootstrap Var(D) = 0.004468775834683117 (High bound: 0.05904042314758257)
# Run 6: N = 277, M = 23, mu_X = 4.6371, sigma_X = 1.6949, mu_epsilon = 0.7938, sigma_1 = 1.9769, sigma_2 = 0.5775
# Run 6: Mean bootstrap Var(D) = 0.053722453678759635 (High bound: 0.14061839665422693)
# Run 7: N = 66, M = 18, mu_X = 2.5728, sigma_X = 0.9017, mu_epsilon = -2.3612, sigma_1 = 1.7566, sigma_2 = 0.9042
# Run 7: Mean bootstrap Var(D) = 0.03206414949548775 (High bound: 0.07442587477389037)
# Run 8: N = 12, M = 6, mu_X = 1.7193, sigma_X = 0.7985, mu_epsilon = -2.222, sigma_1 = 1.2037, sigma_2 = 0.2564
# Run 8: Mean bootstrap Var(D) = 0.031235341135233612 (High bound: 0.15950045488230338)
# Run 9: N = 14, M = 7, mu_X = 3.183, sigma_X = 1.5498, mu_epsilon = 1.1278, sigma_1 = 2.0584, sigma_2 = 0.9204
# Run 9: Mean bootstrap Var(D) = 0.10535611998768869 (High bound: 0.5347146718210061)
# Run 10: N = 1351, M = 289, mu_X = -1.2511, sigma_X = 2.5314, mu_epsilon = 0.8816, sigma_1 = 2.5013, sigma_2 = 0.1177
# Run 10: Mean bootstrap Var(D) = 0.0060268330924331415 (High bound: 0.026936968352792884)
# Run 1: N = 14, M = 6, mu_X = 0.1246, sigma_X = 1.4584, mu_epsilon = 2.7729, sigma_1 = 2.5891, sigma_2 = 2.5228
# Run 1: Mean bootstrap Var(D) = 0.2486176987264208 (High bound: 0.631173436712379)
# Run 2: N = 1806, M = 1012, mu_X = 5.2561, sigma_X = 0.4191, mu_epsilon = 2.6012, sigma_1 = 1.1666, sigma_2 = 0.7229
# Run 2: Mean bootstrap Var(D) = 0.00010953406400032624 (High bound: 0.0003292095321341983)
# Run 3: N = 12, M = 6, mu_X = -3.7782, sigma_X = 1.0213, mu_epsilon = 0.8031, sigma_1 = 3.047, sigma_2 = 0.2889
# Run 3: Mean bootstrap Var(D) = 0.07811843555450568 (High bound: 0.2741656335926779)
# Run 4: N = 1864, M = 424, mu_X = -4.3626, sigma_X = 0.9548, mu_epsilon = -3.3752, sigma_1 = 1.8571, sigma_2 = 1.2954
# Run 4: Mean bootstrap Var(D) = 0.0021103609983989754 (High bound: 0.0036840467755449224)
# Run 5: N = 306, M = 134, mu_X = 5.4907, sigma_X = 1.0198, mu_epsilon = -3.9846, sigma_1 = 0.7759, sigma_2 = 0.2197
# Run 5: Mean bootstrap Var(D) = 0.0009072202201590411 (High bound: 0.01103871994147365)
# Run 6: N = 131, M = 50, mu_X = -2.7067, sigma_X = 1.4356, mu_epsilon = -0.3167, sigma_1 = 1.0311, sigma_2 = 0.2065
# Run 6: Mean bootstrap Var(D) = 0.004474078668325525 (High bound: 0.05487397350346278)
# Run 7: N = 37, M = 14, mu_X = 2.8401, sigma_X = 0.7274, mu_epsilon = 3.5652, sigma_1 = 0.6545, sigma_2 = 0.217
# Run 7: Mean bootstrap Var(D) = 0.006619770681217766 (High bound: 0.05137277819181881)
# Run 8: N = 138, M = 47, mu_X = -1.8517, sigma_X = 1.9041, mu_epsilon = -1.066, sigma_1 = 2.6505, sigma_2 = 2.2823
# Run 8: Mean bootstrap Var(D) = 0.04012125165322447 (High bound: 0.1290168133873495)
# Run 9: N = 15, M = 10, mu_X = -0.7811, sigma_X = 1.7687, mu_epsilon = -3.833, sigma_1 = 2.4478, sigma_2 = 1.2554
# Run 9: Mean bootstrap Var(D) = 0.07193690255912029 (High bound: 0.5321214897387758)
# Run 10: N = 1919, M = 111, mu_X = 6.8773, sigma_X = 0.8683, mu_epsilon = 0.8209, sigma_1 = 2.6403, sigma_2 = 1.0636
# Run 10: Mean bootstrap Var(D) = 0.008926844873267293 (High bound: 0.011263201791005067)
# Run 1: N = 932, M = 338, mu_X = 0.649, sigma_X = 1.8543, mu_epsilon = -1.6774, sigma_1 = 0.8642, sigma_2 = 0.7869
# Run 1: Mean bootstrap Var(D) = 0.000667399455131437 (High bound: 0.013369888355207606)
# Run 2: N = 183, M = 111, mu_X = 0.4247, sigma_X = 1.9404, mu_epsilon = -2.248, sigma_1 = 2.0003, sigma_2 = 1.5643
# Run 2: Mean bootstrap Var(D) = 0.007091824467301356 (High bound: 0.05822563276444885)
# Run 3: N = 2043, M = 208, mu_X = -0.4349, sigma_X = 1.09, mu_epsilon = -6.8249, sigma_1 = 1.1022, sigma_2 = 1.0695
# Run 3: Mean bootstrap Var(D) = 0.0037758036240924733 (High bound: 0.007816886874017905)
# Run 4: N = 12, M = 4, mu_X = 1.0797, sigma_X = 1.4177, mu_epsilon = 0.8624, sigma_1 = 0.6648, sigma_2 = 0.5251
# Run 4: Mean bootstrap Var(D) = 0.034924868825442185 (High bound: 0.5595672397971156)
# Run 5: N = 1292, M = 110, mu_X = 0.8552, sigma_X = 2.6814, mu_epsilon = -3.3879, sigma_1 = 1.637, sigma_2 = 1.173
# Run 5: Mean bootstrap Var(D) = 0.012172311236443346 (High bound: 0.06409866117092262)
# Run 6: N = 20, M = 10, mu_X = -1.2264, sigma_X = 2.6734, mu_epsilon = -0.5743, sigma_1 = 1.6122, sigma_2 = 1.4044
# Run 6: Mean bootstrap Var(D) = 0.06651277594398736 (High bound: 1.0170489154057782)
# Run 7: N = 21, M = 5, mu_X = 1.6954, sigma_X = 0.8242, mu_epsilon = 3.311, sigma_1 = 0.8223, sigma_2 = 0.314
# Run 7: Mean bootstrap Var(D) = 0.03832465068917682 (High bound: 0.16626901627548563)
# Run 8: N = 51, M = 15, mu_X = 1.1762, sigma_X = 2.6139, mu_epsilon = 2.2661, sigma_1 = 2.723, sigma_2 = 0.8683
# Run 8: Mean bootstrap Var(D) = 0.1276114320392693 (High bound: 0.6044284067737451)
# Run 9: N = 1124, M = 177, mu_X = 4.5641, sigma_X = 0.9655, mu_epsilon = 0.6052, sigma_1 = 2.0299, sigma_2 = 0.8808
# Run 9: Mean bootstrap Var(D) = 0.004589119683846927 (High bound: 0.008331103577676111)
# Run 10: N = 511, M = 159, mu_X = -0.1622, sigma_X = 1.5981, mu_epsilon = -2.4832, sigma_1 = 2.2498, sigma_2 = 0.874
# Run 10: Mean bootstrap Var(D) = 0.0071268761068129455 (High bound: 0.02415425067715961)
# Run 1: N = 52, M = 6, mu_X = -3.2941, sigma_X = 0.768, mu_epsilon = 8.0012, sigma_1 = 2.5707, sigma_2 = 0.3187
# Run 1: Mean bootstrap Var(D) = 0.09023012935039043 (High bound: 0.13656347109424083)
# Run 2: N = 2330, M = 279, mu_X = 0.1507, sigma_X = 1.7227, mu_epsilon = 0.6431, sigma_1 = 2.082, sigma_2 = 0.1463
# Run 2: Mean bootstrap Var(D) = 0.004345723650007438 (High bound: 0.012211032636550635)
# Run 3: N = 48, M = 17, mu_X = 2.3689, sigma_X = 0.8822, mu_epsilon = -4.6828, sigma_1 = 1.8498, sigma_2 = 0.3465
# Run 3: Mean bootstrap Var(D) = 0.02329131399726306 (High bound: 0.0701453454682607)
# Run 4: N = 81, M = 8, mu_X = 2.6565, sigma_X = 1.3517, mu_epsilon = 9.1966, sigma_1 = 3.8264, sigma_2 = 2.9353
# Run 4: Mean bootstrap Var(D) = 0.3264600608085881 (High bound: 0.41351418218255687)
# Run 5: N = 349, M = 13, mu_X = 5.2121, sigma_X = 2.6019, mu_epsilon = -0.2434, sigma_1 = 1.8215, sigma_2 = 1.4937
# Run 5: Mean bootstrap Var(D) = 0.17681980023287433 (High bound: 0.4958361271117112)
# Run 6: N = 12, M = 8, mu_X = -6.0459, sigma_X = 1.3344, mu_epsilon = -2.8451, sigma_1 = 2.314, sigma_2 = 1.5316
# Run 6: Mean bootstrap Var(D) = 0.07114760630957133 (High bound: 0.39773899298257176)
# Run 7: N = 806, M = 169, mu_X = -3.5212, sigma_X = 2.222, mu_epsilon = -2.553, sigma_1 = 2.1394, sigma_2 = 1.5407
# Run 7: Mean bootstrap Var(D) = 0.010757856489349286 (High bound: 0.04005029104655991)
# Run 8: N = 395, M = 79, mu_X = 0.6058, sigma_X = 0.6964, mu_epsilon = 1.8279, sigma_1 = 1.765, sigma_2 = 0.4812
# Run 8: Mean bootstrap Var(D) = 0.005028880654656437 (High bound: 0.00960008590733641)
# Run 9: N = 192, M = 92, mu_X = 1.7647, sigma_X = 1.8913, mu_epsilon = -4.8573, sigma_1 = 0.4475, sigma_2 = 0.3609
# Run 9: Mean bootstrap Var(D) = 0.0002788755173190004 (High bound: 0.05251452807545171)
# Run 10: N = 129, M = 54, mu_X = 1.504, sigma_X = 0.6419, mu_epsilon = 1.9879, sigma_1 = 1.8637, sigma_2 = 0.9185
# Run 10: Mean bootstrap Var(D) = 0.006208006530973927 (High bound: 0.013993529392924389)
# Run 1: N = 200, M = 95, mu_X = 0.3681, sigma_X = 1.7298, mu_epsilon = 1.1587, sigma_1 = 0.3809, sigma_2 = 0.1449
# Run 1: Mean bootstrap Var(D) = 0.0001437941417391644 (High bound: 0.042022194970777214)
# Run 2: N = 2464, M = 862, mu_X = -0.1259, sigma_X = 3.1001, mu_epsilon = -1.2706, sigma_1 = 1.7478, sigma_2 = 1.607
# Run 2: Mean bootstrap Var(D) = 0.001195726734798368 (High bound: 0.015076866045107662)
# Run 3: N = 160, M = 40, mu_X = -5.5345, sigma_X = 1.0331, mu_epsilon = -4.2529, sigma_1 = 1.2251, sigma_2 = 0.3918
# Run 3: Mean bootstrap Var(D) = 0.00966085100540591 (High bound: 0.03606006326794029)
# Run 4: N = 1532, M = 620, mu_X = 3.0179, sigma_X = 1.3933, mu_epsilon = -3.0649, sigma_1 = 0.9192, sigma_2 = 0.8441
# Run 4: Mean bootstrap Var(D) = 0.0005196981856375735 (High bound: 0.004555860834585873)
# Run 5: N = 134, M = 65, mu_X = 1.8128, sigma_X = 1.3073, mu_epsilon = 2.0331, sigma_1 = 1.5086, sigma_2 = 1.2798
# Run 5: Mean bootstrap Var(D) = 0.008821185548740578 (High bound: 0.044212505007300576)
# Run 6: N = 42, M = 15, mu_X = 0.6133, sigma_X = 1.4124, mu_epsilon = -2.8457, sigma_1 = 1.8125, sigma_2 = 0.6303
# Run 6: Mean bootstrap Var(D) = 0.046145652894427 (High bound: 0.1940312561108748)
# Run 7: N = 1783, M = 419, mu_X = 4.2398, sigma_X = 2.7168, mu_epsilon = -3.0462, sigma_1 = 1.032, sigma_2 = 0.1596
# Run 7: Mean bootstrap Var(D) = 0.0005514443888029327 (High bound: 0.018608588888509685)
# Run 8: N = 11, M = 2, mu_X = 4.0199, sigma_X = 1.7518, mu_epsilon = 1.1435, sigma_1 = 0.9818, sigma_2 = 0.137
# Run 8: Mean bootstrap Var(D) = 0.14300634514005306 (High bound: 1.3185686702027564)
# Run 9: N = 295, M = 20, mu_X = -1.7413, sigma_X = 2.8945, mu_epsilon = -1.8808, sigma_1 = 1.7976, sigma_2 = 0.1946
# Run 9: Mean bootstrap Var(D) = 0.063439929886898 (High bound: 0.34613601279594064)
# Run 10: N = 754, M = 173, mu_X = -3.9526, sigma_X = 1.5116, mu_epsilon = 5.3132, sigma_1 = 2.6952, sigma_2 = 0.1667
# Run 10: Mean bootstrap Var(D) = 0.006884163879580299 (High bound: 0.018138657337197453)
# Run 1: N = 11, M = 2, mu_X = -4.7348, sigma_X = 1.6341, mu_epsilon = -2.108, sigma_1 = 2.2073, sigma_2 = 1.0794
# Run 1: Mean bootstrap Var(D) = 0.8088636841660929 (High bound: 1.7589496536118823)
# Run 2: N = 418, M = 243, mu_X = -7.8405, sigma_X = 2.3677, mu_epsilon = 1.9872, sigma_1 = 1.0009, sigma_2 = 0.6606
# Run 2: Mean bootstrap Var(D) = 0.0006706910510406041 (High bound: 0.03503568262438868)
# Run 3: N = 509, M = 123, mu_X = 2.4858, sigma_X = 1.1972, mu_epsilon = 2.8624, sigma_1 = 1.3597, sigma_2 = 0.5454
# Run 3: Mean bootstrap Var(D) = 0.00416979400409244 (High bound: 0.015907450660600328)
# Run 4: N = 12, M = 2, mu_X = -1.1064, sigma_X = 1.7949, mu_epsilon = 7.2867, sigma_1 = 1.8601, sigma_2 = 0.3072
# Run 4: Mean bootstrap Var(D) = 0.4927328748729707 (High bound: 1.676958075750758)
# Run 5: N = 381, M = 76, mu_X = 0.8019, sigma_X = 1.6793, mu_epsilon = 7.8235, sigma_1 = 1.7034, sigma_2 = 0.3045
# Run 5: Mean bootstrap Var(D) = 0.011424629505295223 (High bound: 0.04502658416767265)
# Run 6: N = 814, M = 301, mu_X = -1.0083, sigma_X = 1.9195, mu_epsilon = 0.5455, sigma_1 = 0.8804, sigma_2 = 0.6231
# Run 6: Mean bootstrap Var(D) = 0.0006126028233875709 (High bound: 0.015874414478967636)
# Run 7: N = 43, M = 19, mu_X = -0.1013, sigma_X = 2.1607, mu_epsilon = -2.9358, sigma_1 = 2.6175, sigma_2 = 0.783
# Run 7: Mean bootstrap Var(D) = 0.06177984410961012 (High bound: 0.36854545462070254)
# Run 8: N = 12, M = 8, mu_X = -1.4068, sigma_X = 0.841, mu_epsilon = 0.5426, sigma_1 = 1.4642, sigma_2 = 0.3314
# Run 8: Mean bootstrap Var(D) = 0.021378469888988873 (High bound: 0.14600472315780058)
# Run 9: N = 763, M = 457, mu_X = -0.6792, sigma_X = 2.8631, mu_epsilon = 2.7123, sigma_1 = 0.8811, sigma_2 = 0.6622
# Run 9: Mean bootstrap Var(D) = 0.00020415189182211997 (High bound: 0.02723962468527802)
# Run 10: N = 69, M = 37, mu_X = -1.0189, sigma_X = 0.3459, mu_epsilon = 4.9695, sigma_1 = 0.9368, sigma_2 = 0.7175
# Run 10: Mean bootstrap Var(D) = 0.002302703223467105 (High bound: 0.006153526594619347)
# Run 1: N = 38, M = 15, mu_X = -1.1646, sigma_X = 3.8177, mu_epsilon = -1.2125, sigma_1 = 0.7498, sigma_2 = 0.3282
# Run 1: Mean bootstrap Var(D) = 0.004160858606799709 (High bound: 1.138883940609153)
# Run 2: N = 19, M = 4, mu_X = -1.688, sigma_X = 1.7889, mu_epsilon = -2.8071, sigma_1 = 0.6218, sigma_2 = 0.1695
# Run 2: Mean bootstrap Var(D) = 0.022970330757957336 (High bound: 0.7057505279459022)
# Run 3: N = 494, M = 32, mu_X = 0.4285, sigma_X = 0.3315, mu_epsilon = 4.5394, sigma_1 = 1.1153, sigma_2 = 0.2879
# Run 3: Mean bootstrap Var(D) = 0.004106519934790034 (High bound: 0.005340916250131198)
# Run 4: N = 2985, M = 710, mu_X = 0.1864, sigma_X = 1.2464, mu_epsilon = -0.5581, sigma_1 = 1.2774, sigma_2 = 1.1638
# Run 4: Mean bootstrap Var(D) = 0.0009779271125660333 (High bound: 0.003254170776767641)
# Run 5: N = 17, M = 12, mu_X = -0.4615, sigma_X = 2.7595, mu_epsilon = 4.4242, sigma_1 = 1.5412, sigma_2 = 0.5609
# Run 5: Mean bootstrap Var(D) = 0.02031373153855537 (High bound: 0.9789201323238446)
# Run 6: N = 519, M = 193, mu_X = -1.3905, sigma_X = 1.6178, mu_epsilon = -1.029, sigma_1 = 0.6888, sigma_2 = 0.5537
# Run 6: Mean bootstrap Var(D) = 0.0006300350646115056 (High bound: 0.017532796149012785)
# Run 7: N = 477, M = 166, mu_X = 1.1258, sigma_X = 1.0929, mu_epsilon = 1.8151, sigma_1 = 1.4614, sigma_2 = 0.5069
# Run 7: Mean bootstrap Var(D) = 0.002652443242493771 (High bound: 0.010795525705803131)
# Run 8: N = 1768, M = 965, mu_X = 0.1474, sigma_X = 2.1059, mu_epsilon = 1.4005, sigma_1 = 2.1778, sigma_2 = 1.2574
# Run 8: Mean bootstrap Var(D) = 0.0008747941291737027 (High bound: 0.007563436029818026)
# Run 9: N = 23, M = 7, mu_X = -2.7678, sigma_X = 1.3406, mu_epsilon = 1.4692, sigma_1 = 1.4995, sigma_2 = 0.4776
# Run 9: Mean bootstrap Var(D) = 0.07745359374758502 (High bound: 0.3400125045434186)
# Run 10: N = 12, M = 8, mu_X = -0.3758, sigma_X = 1.5951, mu_epsilon = -0.669, sigma_1 = 1.5785, sigma_2 = 0.9661
# Run 10: Mean bootstrap Var(D) = 0.044625900530448244 (High bound: 0.5130390734910601)
# Run 1: N = 729, M = 420, mu_X = 3.7758, sigma_X = 1.6141, mu_epsilon = 4.5321, sigma_1 = 1.7237, sigma_2 = 0.902
# Run 1: Mean bootstrap Var(D) = 0.0011036837056257215 (High bound: 0.010327079396104888)
# Run 2: N = 533, M = 59, mu_X = 0.8558, sigma_X = 1.7159, mu_epsilon = 5.1416, sigma_1 = 3.2128, sigma_2 = 1.5654
# Run 2: Mean bootstrap Var(D) = 0.0462523960726451 (High bound: 0.07592933907763964)
# Run 3: N = 1175, M = 467, mu_X = -3.1504, sigma_X = 1.3349, mu_epsilon = -3.6255, sigma_1 = 1.974, sigma_2 = 1.5493
# Run 3: Mean bootstrap Var(D) = 0.0019980628992378843 (High bound: 0.006539332241371707)
# Run 4: N = 2374, M = 598, mu_X = 0.6812, sigma_X = 0.9201, mu_epsilon = 4.3589, sigma_1 = 0.8941, sigma_2 = 0.4239
# Run 4: Mean bootstrap Var(D) = 0.00037790978460743664 (High bound: 0.0019007268154104104)
# Run 5: N = 104, M = 63, mu_X = 1.8375, sigma_X = 1.1032, mu_epsilon = 5.8197, sigma_1 = 2.1642, sigma_2 = 0.9155
# Run 5: Mean bootstrap Var(D) = 0.0067142174688211735 (High bound: 0.034529055678490246)
# Run 6: N = 1461, M = 31, mu_X = -0.7783, sigma_X = 0.4741, mu_epsilon = -1.166, sigma_1 = 2.5383, sigma_2 = 1.6538
# Run 6: Mean bootstrap Var(D) = 0.01264181337354897 (High bound: 0.013894767071293494)
# Run 7: N = 1452, M = 408, mu_X = -2.0169, sigma_X = 1.8372, mu_epsilon = -3.2235, sigma_1 = 1.9938, sigma_2 = 1.4311
# Run 7: Mean bootstrap Var(D) = 0.003209155611922484 (High bound: 0.012348615012606715)
# Run 8: N = 26, M = 11, mu_X = 3.9286, sigma_X = 1.7018, mu_epsilon = 2.666, sigma_1 = 0.6427, sigma_2 = 0.2603
# Run 8: Mean bootstrap Var(D) = 0.006246394163359639 (High bound: 0.32270402962949185)
# Run 9: N = 844, M = 446, mu_X = 0.3578, sigma_X = 1.8031, mu_epsilon = 4.0518, sigma_1 = 3.0598, sigma_2 = 1.6592
# Run 9: Mean bootstrap Var(D) = 0.0028532932680126245 (High bound: 0.012818364013270505)
# Run 10: N = 1587, M = 122, mu_X = -2.9552, sigma_X = 1.1452, mu_epsilon = -1.5184, sigma_1 = 1.8292, sigma_2 = 1.4152
# Run 10: Mean bootstrap Var(D) = 0.010880763465304588 (High bound: 0.016691867472932928)
# Run 1: N = 380, M = 167, mu_X = 3.8037, sigma_X = 2.1969, mu_epsilon = -0.2783, sigma_1 = 1.1473, sigma_2 = 0.4371
# Run 1: Mean bootstrap Var(D) = 0.0014511789855511787 (High bound: 0.039535729377394836)
# Run 2: N = 27, M = 15, mu_X = 0.8683, sigma_X = 2.4421, mu_epsilon = -7.1855, sigma_1 = 0.714, sigma_2 = 0.0245
# Run 2: Mean bootstrap Var(D) = 0.0034014382380918554 (High bound: 0.5418573799450189)
# Run 3: N = 20, M = 6, mu_X = 3.0332, sigma_X = 1.4971, mu_epsilon = 2.6717, sigma_1 = 1.9685, sigma_2 = 1.2035
# Run 3: Mean bootstrap Var(D) = 0.1757853915419641 (High bound: 0.5588897450084374)
# Run 4: N = 299, M = 123, mu_X = -4.0587, sigma_X = 0.4681, mu_epsilon = 0.1127, sigma_1 = 1.8726, sigma_2 = 0.0715
# Run 4: Mean bootstrap Var(D) = 0.0010435294211721942 (High bound: 0.00285926566641754)
# Run 5: N = 100, M = 41, mu_X = -1.5395, sigma_X = 1.095, mu_epsilon = 3.2438, sigma_1 = 1.8105, sigma_2 = 1.1044
# Run 5: Mean bootstrap Var(D) = 0.015378709043576829 (High bound: 0.04973838006316955)
# Run 6: N = 778, M = 138, mu_X = -3.9483, sigma_X = 1.6499, mu_epsilon = -0.105, sigma_1 = 0.9634, sigma_2 = 0.4032
# Run 6: Mean bootstrap Var(D) = 0.0019736207805250423 (High bound: 0.020956381257077626)
# Run 7: N = 1413, M = 757, mu_X = 0.5255, sigma_X = 1.3976, mu_epsilon = 1.7953, sigma_1 = 0.6412, sigma_2 = 0.0711
# Run 7: Mean bootstrap Var(D) = 7.418378632671211e-05 (High bound: 0.0037638693624082757)
# Run 8: N = 1790, M = 744, mu_X = -4.7355, sigma_X = 2.2268, mu_epsilon = 0.2352, sigma_1 = 2.4857, sigma_2 = 2.0597
# Run 8: Mean bootstrap Var(D) = 0.002441900161332308 (High bound: 0.010875737850474531)
# Run 9: N = 24, M = 10, mu_X = 1.9936, sigma_X = 2.6171, mu_epsilon = 1.4137, sigma_1 = 1.2119, sigma_2 = 0.9891
# Run 9: Mean bootstrap Var(D) = 0.03816389462140873 (High bound: 0.8745599103951156)
# Run 10: N = 16, M = 7, mu_X = 2.9702, sigma_X = 0.9884, mu_epsilon = -3.9588, sigma_1 = 1.2201, sigma_2 = 0.1309
# Run 10: Mean bootstrap Var(D) = 0.03610675204811538 (High bound: 0.1958412598981827)
# Run 1: N = 732, M = 374, mu_X = -1.4719, sigma_X = 0.2137, mu_epsilon = -2.7704, sigma_1 = 1.0242, sigma_2 = 0.5293
# Run 1: Mean bootstrap Var(D) = 0.00010245118649531474 (High bound: 0.0002372922703601157)
# Run 2: N = 2910, M = 95, mu_X = 4.5633, sigma_X = 2.1769, mu_epsilon = -4.1571, sigma_1 = 0.6587, sigma_2 = 0.0597
# Run 2: Mean bootstrap Var(D) = 0.0014058388993802389 (High bound: 0.029957579712709775)
# Run 3: N = 92, M = 48, mu_X = -4.3647, sigma_X = 1.6209, mu_epsilon = 2.0077, sigma_1 = 0.6624, sigma_2 = 0.3646
# Run 3: Mean bootstrap Var(D) = 0.0013448752903065131 (High bound: 0.07774939335263636)
# Run 4: N = 10, M = 3, mu_X = 1.5544, sigma_X = 3.5354, mu_epsilon = 0.8918, sigma_1 = 1.7184, sigma_2 = 0.5879
# Run 4: Mean bootstrap Var(D) = 0.22792996573406282 (High bound: 4.1887889079702525)
# Run 5: N = 184, M = 93, mu_X = -1.9346, sigma_X = 1.0063, mu_epsilon = 1.1187, sigma_1 = 0.8672, sigma_2 = 0.3412
# Run 5: Mean bootstrap Var(D) = 0.0013806065384758303 (High bound: 0.01660372557951774)
# Run 6: N = 1251, M = 215, mu_X = -3.729, sigma_X = 1.2126, mu_epsilon = 0.7204, sigma_1 = 2.1251, sigma_2 = 0.4523
# Run 6: Mean bootstrap Var(D) = 0.0041326147208873626 (High bound: 0.009384250395362897)
# Run 7: N = 1454, M = 99, mu_X = 2.5395, sigma_X = 1.6032, mu_epsilon = -1.0066, sigma_1 = 3.1822, sigma_2 = 0.8797
# Run 7: Mean bootstrap Var(D) = 0.021736551205304374 (High bound: 0.0349699465900738)
# Run 8: N = 41, M = 22, mu_X = 5.2137, sigma_X = 1.423, mu_epsilon = 1.8495, sigma_1 = 1.4825, sigma_2 = 0.6077
# Run 8: Mean bootstrap Var(D) = 0.016674257597241463 (High bound: 0.14401771140270506)
# Run 9: N = 3117, M = 1682, mu_X = 0.2849, sigma_X = 0.9371, mu_epsilon = -4.9637, sigma_1 = 1.5083, sigma_2 = 0.8492
# Run 9: Mean bootstrap Var(D) = 0.00019703084377646526 (High bound: 0.0009172128319104478)
# Run 10: N = 1822, M = 778, mu_X = 3.0646, sigma_X = 0.8281, mu_epsilon = 0.6474, sigma_1 = 0.9041, sigma_2 = 0.0672
# Run 10: Mean bootstrap Var(D) = 0.00016489132525567235 (High bound: 0.0012946455252745414)
# Run 1: N = 10, M = 3, mu_X = -0.7047, sigma_X = 1.925, mu_epsilon = 5.0662, sigma_1 = 1.3932, sigma_2 = 1.0634
# Run 1: Mean bootstrap Var(D) = 0.21358251232084524 (High bound: 1.4897374450249536)
# Run 2: N = 162, M = 46, mu_X = 3.1237, sigma_X = 2.4557, mu_epsilon = 4.4202, sigma_1 = 2.6782, sigma_2 = 0.4304
# Run 2: Mean bootstrap Var(D) = 0.035582373151669136 (High bound: 0.17311174951445518)
# Run 3: N = 78, M = 5, mu_X = -2.3834, sigma_X = 1.5062, mu_epsilon = -5.2232, sigma_1 = 2.8721, sigma_2 = 0.9396
# Run 3: Mean bootstrap Var(D) = 0.4180864702505963 (High bound: 0.6038886678298231)
# Run 4: N = 1340, M = 308, mu_X = 1.3244, sigma_X = 0.273, mu_epsilon = 1.1982, sigma_1 = 1.2828, sigma_2 = 0.6121
# Run 4: Mean bootstrap Var(D) = 0.00032229318933502593 (High bound: 0.00045817261609649074)
# Run 5: N = 810, M = 182, mu_X = 1.1027, sigma_X = 1.3482, mu_epsilon = -0.3974, sigma_1 = 1.047, sigma_2 = 0.9943
# Run 5: Mean bootstrap Var(D) = 0.0030250094792331453 (High bound: 0.013444349205798017)
# Run 6: N = 60, M = 28, mu_X = -3.1644, sigma_X = 2.2883, mu_epsilon = -1.2341, sigma_1 = 1.98, sigma_2 = 1.8625
# Run 6: Mean bootstrap Var(D) = 0.044482504542879095 (High bound: 0.29427157256544345)
# Run 7: N = 86, M = 41, mu_X = -2.3768, sigma_X = 0.4286, mu_epsilon = 4.1789, sigma_1 = 1.3348, sigma_2 = 1.1549
# Run 7: Mean bootstrap Var(D) = 0.003922489379373287 (High bound: 0.008624412909050071)
# Run 8: N = 266, M = 86, mu_X = 1.2012, sigma_X = 2.0501, mu_epsilon = 0.8101, sigma_1 = 1.0186, sigma_2 = 0.2621
# Run 8: Mean bootstrap Var(D) = 0.0024167022601025248 (High bound: 0.05906212222781895)
# Run 9: N = 261, M = 62, mu_X = 1.8464, sigma_X = 1.5566, mu_epsilon = -0.7596, sigma_1 = 0.2905, sigma_2 = 0.228
# Run 9: Mean bootstrap Var(D) = 0.00023180590553674007 (High bound: 0.03948471108588113)
# Run 10: N = 11, M = 7, mu_X = 1.8605, sigma_X = 0.2259, mu_epsilon = -3.6937, sigma_1 = 1.6745, sigma_2 = 1.2097
# Run 10: Mean bootstrap Var(D) = 0.004958823764257453 (High bound: 0.01445201501921519)
# Run 1: N = 1603, M = 455, mu_X = -1.7226, sigma_X = 2.4613, mu_epsilon = 0.9282, sigma_1 = 0.5434, sigma_2 = 0.3484
# Run 1: Mean bootstrap Var(D) = 9.448528090900821e-05 (High bound: 0.014609194048760429)
# Run 2: N = 187, M = 98, mu_X = 0.5898, sigma_X = 0.9037, mu_epsilon = -3.5624, sigma_1 = 3.1036, sigma_2 = 2.2044
# Run 2: Mean bootstrap Var(D) = 0.006563230709003196 (High bound: 0.016092292693694814)
# Run 3: N = 1465, M = 242, mu_X = 1.1088, sigma_X = 2.0154, mu_epsilon = -1.2683, sigma_1 = 1.9665, sigma_2 = 1.9164
# Run 3: Mean bootstrap Var(D) = 0.008816670486658582 (High bound: 0.02373648721965624)
# Run 4: N = 1668, M = 839, mu_X = -0.9366, sigma_X = 0.8905, mu_epsilon = 6.0167, sigma_1 = 1.4652, sigma_2 = 0.6462
# Run 4: Mean bootstrap Var(D) = 0.00035737634932898866 (High bound: 0.001612986136645839)
# Run 5: N = 197, M = 21, mu_X = 2.2213, sigma_X = 0.5023, mu_epsilon = -1.2441, sigma_1 = 1.4909, sigma_2 = 1.2565
# Run 5: Mean bootstrap Var(D) = 0.01735488912583188 (High bound: 0.022199448283731136)
# Run 6: N = 2142, M = 964, mu_X = -3.9409, sigma_X = 1.0736, mu_epsilon = 4.0256, sigma_1 = 0.5519, sigma_2 = 0.0774
# Run 6: Mean bootstrap Var(D) = 5.263256611864543e-05 (High bound: 0.0016412922406073135)
# Run 7: N = 305, M = 142, mu_X = 4.4657, sigma_X = 1.1889, mu_epsilon = 1.3071, sigma_1 = 0.6893, sigma_2 = 0.4275
# Run 7: Mean bootstrap Var(D) = 0.0006990702484245747 (High bound: 0.014287732377174504)
# Run 8: N = 290, M = 101, mu_X = -0.8148, sigma_X = 1.7699, mu_epsilon = -5.0224, sigma_1 = 2.4722, sigma_2 = 1.2853
# Run 8: Mean bootstrap Var(D) = 0.01368203520458692 (High bound: 0.048939316279119724)
# Run 9: N = 14, M = 3, mu_X = -9.0719, sigma_X = 0.6643, mu_epsilon = -0.8989, sigma_1 = 1.3516, sigma_2 = 0.6947
# Run 9: Mean bootstrap Var(D) = 0.12866334418453226 (High bound: 0.23423715969553402)
# Run 10: N = 22, M = 14, mu_X = 7.4857, sigma_X = 0.8072, mu_epsilon = 3.3559, sigma_1 = 0.9397, sigma_2 = 0.1692
# Run 10: Mean bootstrap Var(D) = 0.007027758749719362 (High bound: 0.07429561640006774)
# Run 1: N = 2619, M = 547, mu_X = -0.2842, sigma_X = 1.7657, mu_epsilon = -5.4489, sigma_1 = 1.4852, sigma_2 = 0.5301
# Run 1: Mean bootstrap Var(D) = 0.0012408924101377035 (High bound: 0.00689759647626585)
# Run 2: N = 1560, M = 153, mu_X = 2.1246, sigma_X = 0.8378, mu_epsilon = 2.3535, sigma_1 = 2.0848, sigma_2 = 2.0429
# Run 2: Mean bootstrap Var(D) = 0.0064323927928941664 (High bound: 0.008352741915990322)
# Run 3: N = 2047, M = 846, mu_X = 0.3879, sigma_X = 1.6954, mu_epsilon = 1.9368, sigma_1 = 1.0006, sigma_2 = 0.1029
# Run 3: Mean bootstrap Var(D) = 0.0002126049169765108 (High bound: 0.004577693541621044)
# Run 4: N = 864, M = 236, mu_X = 4.6315, sigma_X = 1.0662, mu_epsilon = 0.1449, sigma_1 = 1.5778, sigma_2 = 0.9404
# Run 4: Mean bootstrap Var(D) = 0.002684191228753921 (High bound: 0.007625825563846913)
# Run 5: N = 1455, M = 129, mu_X = 2.9959, sigma_X = 1.0984, mu_epsilon = -1.664, sigma_1 = 0.8672, sigma_2 = 0.8394
# Run 5: Mean bootstrap Var(D) = 0.0038065965275505395 (High bound: 0.011175367846185506)
# Run 6: N = 913, M = 545, mu_X = 2.0664, sigma_X = 1.6184, mu_epsilon = -2.2407, sigma_1 = 1.9497, sigma_2 = 0.8316
# Run 6: Mean bootstrap Var(D) = 0.001037794075515208 (High bound: 0.008117441566143907)
# Run 7: N = 21, M = 5, mu_X = 2.7937, sigma_X = 1.7125, mu_epsilon = 2.3787, sigma_1 = 0.9617, sigma_2 = 0.7537
# Run 7: Mean bootstrap Var(D) = 0.07587958875924099 (High bound: 0.6438516945938944)
# Run 8: N = 3011, M = 1382, mu_X = -1.5695, sigma_X = 1.5792, mu_epsilon = -0.48, sigma_1 = 2.7843, sigma_2 = 0.7485
# Run 8: Mean bootstrap Var(D) = 0.0006488945593694353 (High bound: 0.0029486242845325494)
# Run 9: N = 14, M = 2, mu_X = 1.6095, sigma_X = 1.9261, mu_epsilon = 2.229, sigma_1 = 1.7959, sigma_2 = 0.5964
# Run 9: Mean bootstrap Var(D) = 0.5539901592047338 (High bound: 1.8947269025044653)
# Run 10: N = 250, M = 122, mu_X = -0.6503, sigma_X = 1.9816, mu_epsilon = -4.7935, sigma_1 = 0.7998, sigma_2 = 0.3356
# Run 10: Mean bootstrap Var(D) = 0.0007603570423143362 (High bound: 0.04478803867187861)
# Run 1: N = 12, M = 8, mu_X = -1.4159, sigma_X = 2.3195, mu_epsilon = 3.6703, sigma_1 = 1.1976, sigma_2 = 0.7642
# Run 1: Mean bootstrap Var(D) = 0.02800451385187045 (High bound: 0.989156715893106)
# Run 2: N = 18, M = 5, mu_X = -1.8499, sigma_X = 2.2235, mu_epsilon = -2.8614, sigma_1 = 1.8684, sigma_2 = 1.5113
# Run 2: Mean bootstrap Var(D) = 0.27758787820495456 (High bound: 1.2995976000407472)
# Run 3: N = 22, M = 6, mu_X = 0.3713, sigma_X = 1.8206, mu_epsilon = -3.2875, sigma_1 = 2.0792, sigma_2 = 1.203
# Run 3: Mean bootstrap Var(D) = 0.21479213990642412 (High bound: 0.7714777458487714)
# Run 4: N = 184, M = 54, mu_X = 0.4603, sigma_X = 1.4519, mu_epsilon = -1.0691, sigma_1 = 2.1644, sigma_2 = 1.3989
# Run 4: Mean bootstrap Var(D) = 0.023089785169273097 (High bound: 0.06293454887749925)
# Run 5: N = 567, M = 271, mu_X = -3.7455, sigma_X = 1.7673, mu_epsilon = -0.8151, sigma_1 = 2.1044, sigma_2 = 1.5702
# Run 5: Mean bootstrap Var(D) = 0.0036754628626812415 (High bound: 0.019292871064019963)
# Run 6: N = 769, M = 326, mu_X = 3.2457, sigma_X = 0.8858, mu_epsilon = 2.6869, sigma_1 = 0.8725, sigma_2 = 0.5746
# Run 6: Mean bootstrap Var(D) = 0.0005890900785941053 (High bound: 0.0037352083264573467)
# Run 7: N = 248, M = 31, mu_X = 0.2427, sigma_X = 1.2989, mu_epsilon = 5.9334, sigma_1 = 1.9054, sigma_2 = 0.438
# Run 7: Mean bootstrap Var(D) = 0.029079657887930353 (High bound: 0.0683067712677301)
# Run 8: N = 1927, M = 1077, mu_X = 0.452, sigma_X = 1.0349, mu_epsilon = 2.1083, sigma_1 = 3.0758, sigma_2 = 2.2126
# Run 8: Mean bootstrap Var(D) = 0.000622956535701666 (High bound: 0.001910177900783842)
# Run 9: N = 1460, M = 80, mu_X = -0.9136, sigma_X = 3.1615, mu_epsilon = 2.1475, sigma_1 = 1.9043, sigma_2 = 0.4766
# Run 9: Mean bootstrap Var(D) = 0.018323121134710293 (High bound: 0.10177963177917425)
# Run 10: N = 35, M = 17, mu_X = 1.5553, sigma_X = 2.7262, mu_epsilon = -0.6594, sigma_1 = 1.804, sigma_2 = 1.7686
# Run 10: Mean bootstrap Var(D) = 0.06006940880359666 (High bound: 0.6505740001725991)
# Run 1: N = 858, M = 234, mu_X = 1.2604, sigma_X = 0.7019, mu_epsilon = -4.8099, sigma_1 = 1.8728, sigma_2 = 1.0333
# Run 1: Mean bootstrap Var(D) = 0.0020759834819429777 (High bound: 0.0037703350720054794)
# Run 2: N = 37, M = 22, mu_X = 3.4554, sigma_X = 1.334, mu_epsilon = -1.9618, sigma_1 = 0.4856, sigma_2 = 0.4119
# Run 2: Mean bootstrap Var(D) = 0.0016763309475328963 (High bound: 0.11880500305006732)
# Run 3: N = 80, M = 49, mu_X = -0.3823, sigma_X = 1.8983, mu_epsilon = -0.293, sigma_1 = 0.6565, sigma_2 = 0.459
# Run 3: Mean bootstrap Var(D) = 0.0010640454388235728 (High bound: 0.11111268833962755)
# Run 4: N = 20, M = 8, mu_X = 4.4464, sigma_X = 1.8023, mu_epsilon = -0.526, sigma_1 = 2.8583, sigma_2 = 1.9421
# Run 4: Mean bootstrap Var(D) = 0.2158943621526472 (High bound: 0.6768489251591157)
# Run 5: N = 242, M = 132, mu_X = 3.8821, sigma_X = 1.5409, mu_epsilon = 2.7067, sigma_1 = 2.0636, sigma_2 = 0.174
# Run 5: Mean bootstrap Var(D) = 0.004080080317154607 (High bound: 0.028813635220211985)
# Run 6: N = 118, M = 51, mu_X = 2.3631, sigma_X = 3.2843, mu_epsilon = 2.2382, sigma_1 = 1.9698, sigma_2 = 0.7589
# Run 6: Mean bootstrap Var(D) = 0.015066565105492365 (High bound: 0.2893884583666153)
# Run 7: N = 48, M = 11, mu_X = 0.2029, sigma_X = 1.6001, mu_epsilon = 4.8554, sigma_1 = 1.8381, sigma_2 = 1.4039
# Run 7: Mean bootstrap Var(D) = 0.1143832931247625 (High bound: 0.33990806911854915)
# Run 8: N = 1031, M = 515, mu_X = -3.1328, sigma_X = 1.3677, mu_epsilon = 2.33, sigma_1 = 1.6761, sigma_2 = 0.8012
# Run 8: Mean bootstrap Var(D) = 0.0009313596193469604 (High bound: 0.0059336479908594685)
# Run 9: N = 332, M = 36, mu_X = 0.4603, sigma_X = 0.8799, mu_epsilon = -3.1982, sigma_1 = 0.9659, sigma_2 = 0.9035
# Run 9: Mean bootstrap Var(D) = 0.015016913997910301 (High bound: 0.03029361356966795)
# Run 10: N = 60, M = 19, mu_X = 4.9559, sigma_X = 1.2112, mu_epsilon = -0.4209, sigma_1 = 1.8441, sigma_2 = 1.1637
# Run 10: Mean bootstrap Var(D) = 0.04560225316393816 (High bound: 0.1248193440390756)
# Run 1: N = 429, M = 199, mu_X = -3.1989, sigma_X = 2.4372, mu_epsilon = 1.5773, sigma_1 = 2.088, sigma_2 = 0.8054
# Run 1: Mean bootstrap Var(D) = 0.004027725750036195 (High bound: 0.044465822851291095)
# Run 2: N = 800, M = 470, mu_X = 2.229, sigma_X = 0.9974, mu_epsilon = 4.6584, sigma_1 = 1.6078, sigma_2 = 0.5318
# Run 2: Mean bootstrap Var(D) = 0.0006149100354006198 (High bound: 0.0036395782372745738)
# Run 3: N = 32, M = 21, mu_X = 5.6638, sigma_X = 0.7573, mu_epsilon = 0.8391, sigma_1 = 1.73, sigma_2 = 1.3643
# Run 3: Mean bootstrap Var(D) = 0.012542943171910239 (High bound: 0.0517654324785697)
# Run 4: N = 1602, M = 424, mu_X = 5.8864, sigma_X = 0.6045, mu_epsilon = 5.9071, sigma_1 = 1.2717, sigma_2 = 0.2057
# Run 4: Mean bootstrap Var(D) = 0.0005123959741544742 (High bound: 0.0012755513093660239)
# Run 5: N = 136, M = 63, mu_X = 0.1893, sigma_X = 0.4395, mu_epsilon = 8.1809, sigma_1 = 1.573, sigma_2 = 1.2878
# Run 5: Mean bootstrap Var(D) = 0.002840438809844046 (High bound: 0.005941845780982354)
# Run 6: N = 3097, M = 1186, mu_X = -4.0578, sigma_X = 2.4133, mu_epsilon = -1.6058, sigma_1 = 1.1157, sigma_2 = 0.5639
# Run 6: Mean bootstrap Var(D) = 0.00020149358271899775 (High bound: 0.006378091643191305)
# Run 7: N = 1247, M = 220, mu_X = -2.5887, sigma_X = 1.5684, mu_epsilon = -1.9186, sigma_1 = 1.4163, sigma_2 = 0.4894
# Run 7: Mean bootstrap Var(D) = 0.0027690601540991465 (High bound: 0.013294653836073393)
# Run 8: N = 1461, M = 60, mu_X = 1.2663, sigma_X = 0.5305, mu_epsilon = -2.0465, sigma_1 = 1.0296, sigma_2 = 0.9406
# Run 8: Mean bootstrap Var(D) = 0.006079585168755594 (High bound: 0.007865767897299432)
# Run 9: N = 269, M = 87, mu_X = -2.5955, sigma_X = 1.5325, mu_epsilon = -4.7312, sigma_1 = 1.8524, sigma_2 = 1.587
# Run 9: Mean bootstrap Var(D) = 0.012650838888857065 (High bound: 0.04335967335515012)
# Run 10: N = 156, M = 39, mu_X = -4.4387, sigma_X = 1.7251, mu_epsilon = -0.8006, sigma_1 = 1.4953, sigma_2 = 1.0971
# Run 10: Mean bootstrap Var(D) = 0.023456533057731953 (High bound: 0.10335656353304995)
# Run 1: N = 27, M = 12, mu_X = -4.3491, sigma_X = 2.3447, mu_epsilon = 1.5965, sigma_1 = 1.7122, sigma_2 = 1.0756
# Run 1: Mean bootstrap Var(D) = 0.05751686615625052 (High bound: 0.6438178801623742)
# Run 2: N = 244, M = 36, mu_X = 0.456, sigma_X = 1.6937, mu_epsilon = 3.1847, sigma_1 = 1.2879, sigma_2 = 0.3989
# Run 2: Mean bootstrap Var(D) = 0.015929159429487357 (High bound: 0.08507662746895027)
# Run 3: N = 18, M = 4, mu_X = -2.0228, sigma_X = 1.3556, mu_epsilon = 6.9163, sigma_1 = 2.3712, sigma_2 = 0.7707
# Run 3: Mean bootstrap Var(D) = 0.2981181176895695 (High bound: 0.6490951276750625)
# Run 4: N = 42, M = 16, mu_X = 1.9333, sigma_X = 2.0407, mu_epsilon = -3.1313, sigma_1 = 2.6411, sigma_2 = 0.3252
# Run 4: Mean bootstrap Var(D) = 0.0794085943895665 (High bound: 0.36963456418683566)
# Run 5: N = 1836, M = 557, mu_X = 2.425, sigma_X = 3.4434, mu_epsilon = -1.5234, sigma_1 = 2.5786, sigma_2 = 0.8923
# Run 5: Mean bootstrap Var(D) = 0.0028791815842716833 (High bound: 0.027387594240744398)
# Run 6: N = 345, M = 195, mu_X = -8.3058, sigma_X = 1.4547, mu_epsilon = -3.7067, sigma_1 = 1.8105, sigma_2 = 0.6902
# Run 6: Mean bootstrap Var(D) = 0.002367394487932187 (High bound: 0.0180091797686061)
# Run 7: N = 2330, M = 1394, mu_X = 4.5171, sigma_X = 1.736, mu_epsilon = 2.2806, sigma_1 = 1.3237, sigma_2 = 1.2396
# Run 7: Mean bootstrap Var(D) = 0.00029129790763646223 (High bound: 0.003603079676965289)
# Run 8: N = 321, M = 10, mu_X = 0.2337, sigma_X = 2.3271, mu_epsilon = -4.9945, sigma_1 = 0.7874, sigma_2 = 0.0897
# Run 8: Mean bootstrap Var(D) = 0.02200632638869105 (High bound: 0.31118554769604645)
# Run 9: N = 751, M = 129, mu_X = 3.9384, sigma_X = 2.0094, mu_epsilon = -0.3486, sigma_1 = 1.2563, sigma_2 = 0.4686
# Run 9: Mean bootstrap Var(D) = 0.003882504919299164 (High bound: 0.03336293082140742)
# Run 10: N = 1005, M = 497, mu_X = 0.2966, sigma_X = 1.7538, mu_epsilon = 1.1048, sigma_1 = 0.3998, sigma_2 = 0.303
# Run 10: Mean bootstrap Var(D) = 3.919583648611366e-05 (High bound: 0.008531954769503594)
# Run 1: N = 102, M = 28, mu_X = 0.8459, sigma_X = 0.628, mu_epsilon = -1.099, sigma_1 = 1.671, sigma_2 = 1.3599
# Run 1: Mean bootstrap Var(D) = 0.014998774921464763 (High bound: 0.026107874681056437)
# Run 2: N = 154, M = 17, mu_X = -1.7331, sigma_X = 1.301, mu_epsilon = 2.3604, sigma_1 = 0.3311, sigma_2 = 0.2727
# Run 2: Mean bootstrap Var(D) = 0.0020696095867520333 (High bound: 0.07910837431980747)
# Run 3: N = 11, M = 2, mu_X = -1.2091, sigma_X = 0.9546, mu_epsilon = 0.6218, sigma_1 = 1.074, sigma_2 = 0.5879
# Run 3: Mean bootstrap Var(D) = 0.20316857567491609 (High bound: 0.5658683882756921)
# Run 4: N = 13, M = 7, mu_X = -2.7692, sigma_X = 2.9036, mu_epsilon = -5.0595, sigma_1 = 0.9436, sigma_2 = 0.4932
# Run 4: Mean bootstrap Var(D) = 0.014953722118804655 (High bound: 1.5443287707317555)
# Run 5: N = 41, M = 12, mu_X = -5.8114, sigma_X = 2.0199, mu_epsilon = 1.1693, sigma_1 = 1.7033, sigma_2 = 0.8115
# Run 5: Mean bootstrap Var(D) = 0.0693891637901871 (High bound: 0.43681682128445043)
# Run 6: N = 1938, M = 429, mu_X = 0.2577, sigma_X = 1.6551, mu_epsilon = -6.4942, sigma_1 = 2.3709, sigma_2 = 0.6032
# Run 6: Mean bootstrap Var(D) = 0.002662365633762152 (High bound: 0.008786440255169448)
# Run 7: N = 43, M = 6, mu_X = -0.3557, sigma_X = 2.4306, mu_epsilon = 1.015, sigma_1 = 3.6835, sigma_2 = 1.1757
# Run 7: Mean bootstrap Var(D) = 0.6506446061191088 (High bound: 1.2770455985125686)
# Run 8: N = 29, M = 11, mu_X = 0.2272, sigma_X = 2.1732, mu_epsilon = -0.0261, sigma_1 = 1.6564, sigma_2 = 1.2908
# Run 8: Mean bootstrap Var(D) = 0.08037771053898266 (High bound: 0.5975071741879878)
# Run 9: N = 28, M = 10, mu_X = -2.1493, sigma_X = 1.1918, mu_epsilon = -1.1065, sigma_1 = 0.736, sigma_2 = 0.4018
# Run 9: Mean bootstrap Var(D) = 0.014510875376057305 (High bound: 0.17801243937277877)
# Run 10: N = 101, M = 22, mu_X = 3.8329, sigma_X = 2.2825, mu_epsilon = -2.1857, sigma_1 = 3.4624, sigma_2 = 0.9096
# Run 10: Mean bootstrap Var(D) = 0.11508896064812256 (High bound: 0.32577445256193005)
# Run 1: N = 3066, M = 409, mu_X = 1.7764, sigma_X = 2.4833, mu_epsilon = -3.6789, sigma_1 = 2.9594, sigma_2 = 1.3038
# Run 1: Mean bootstrap Var(D) = 0.007446777882450539 (High bound: 0.019426608591496343)
# Run 2: N = 21, M = 12, mu_X = 2.4876, sigma_X = 1.112, mu_epsilon = 3.6325, sigma_1 = 0.7883, sigma_2 = 0.6405
# Run 2: Mean bootstrap Var(D) = 0.012250046589645479 (High bound: 0.15740994996614333)
# Run 3: N = 52, M = 11, mu_X = 1.8491, sigma_X = 0.5686, mu_epsilon = -4.8437, sigma_1 = 1.774, sigma_2 = 0.9709
# Run 3: Mean bootstrap Var(D) = 0.03487433100321805 (High bound: 0.0530940902710364)
# Run 4: N = 1149, M = 550, mu_X = 0.5453, sigma_X = 2.218, mu_epsilon = 0.366, sigma_1 = 1.6639, sigma_2 = 0.5407
# Run 4: Mean bootstrap Var(D) = 0.0008877072508358132 (High bound: 0.013166888538657783)
# Run 5: N = 81, M = 26, mu_X = 3.2529, sigma_X = 1.7112, mu_epsilon = 0.2426, sigma_1 = 1.519, sigma_2 = 0.1155
# Run 5: Mean bootstrap Var(D) = 0.019889527851862248 (High bound: 0.14510791568492326)
# Run 6: N = 276, M = 63, mu_X = -0.1781, sigma_X = 1.1819, mu_epsilon = -5.2297, sigma_1 = 2.0776, sigma_2 = 1.2082
# Run 6: Mean bootstrap Var(D) = 0.017503706708867316 (High bound: 0.03595559243617745)
# Run 7: N = 512, M = 123, mu_X = -0.3407, sigma_X = 2.3723, mu_epsilon = -0.6758, sigma_1 = 1.4798, sigma_2 = 0.2841
# Run 7: Mean bootstrap Var(D) = 0.004774180897510751 (High bound: 0.05224561619577213)
# Run 8: N = 54, M = 13, mu_X = -5.1455, sigma_X = 1.0919, mu_epsilon = 3.6611, sigma_1 = 1.0628, sigma_2 = 0.2777
# Run 8: Mean bootstrap Var(D) = 0.022938471954142715 (High bound: 0.1129700751042492)
# Run 9: N = 51, M = 22, mu_X = 1.7848, sigma_X = 1.4199, mu_epsilon = -2.2268, sigma_1 = 1.3741, sigma_2 = 0.5061
# Run 9: Mean bootstrap Var(D) = 0.017988762740445512 (High bound: 0.13306055275523343)
# Run 10: N = 2464, M = 114, mu_X = 3.8874, sigma_X = 2.9928, mu_epsilon = -6.0367, sigma_1 = 1.4321, sigma_2 = 0.9334
# Run 10: Mean bootstrap Var(D) = 0.008964588615571586 (High bound: 0.06156793099965755)
# Run 1: N = 1181, M = 709, mu_X = -7.5567, sigma_X = 1.4235, mu_epsilon = 1.4842, sigma_1 = 0.6752, sigma_2 = 0.5618
# Run 1: Mean bootstrap Var(D) = 0.00011155739404543715 (High bound: 0.004481416929144096)
# Run 2: N = 81, M = 49, mu_X = -1.369, sigma_X = 3.2209, mu_epsilon = 0.9287, sigma_1 = 0.8622, sigma_2 = 0.0188
# Run 2: Mean bootstrap Var(D) = 0.0012578548801771684 (High bound: 0.31269958375012485)
# Run 3: N = 57, M = 21, mu_X = 3.2202, sigma_X = 2.3306, mu_epsilon = -1.4474, sigma_1 = 1.4654, sigma_2 = 0.8162
# Run 3: Mean bootstrap Var(D) = 0.025917687369776884 (High bound: 0.3382251349645534)
# Run 4: N = 2562, M = 1534, mu_X = 0.5446, sigma_X = 0.9126, mu_epsilon = -2.0484, sigma_1 = 1.0804, sigma_2 = 0.1276
# Run 4: Mean bootstrap Var(D) = 9.053914247897815e-05 (High bound: 0.0008908761704532328)
# Run 5: N = 16, M = 7, mu_X = -1.0232, sigma_X = 1.1753, mu_epsilon = 3.4087, sigma_1 = 0.1556, sigma_2 = 0.1414
# Run 5: Mean bootstrap Var(D) = 0.00037739538750312674 (High bound: 0.22655348570611994)
# Run 6: N = 171, M = 92, mu_X = -0.6168, sigma_X = 2.0744, mu_epsilon = -4.8394, sigma_1 = 1.521, sigma_2 = 1.0332
# Run 6: Mean bootstrap Var(D) = 0.005650219022250518 (High bound: 0.07296872941876786)
# Run 7: N = 46, M = 17, mu_X = -2.1649, sigma_X = 1.7362, mu_epsilon = -2.2546, sigma_1 = 1.1427, sigma_2 = 0.7456
# Run 7: Mean bootstrap Var(D) = 0.021449734372022924 (High bound: 0.2356255928414374)
# Run 8: N = 20, M = 7, mu_X = -1.7305, sigma_X = 1.7546, mu_epsilon = -1.8884, sigma_1 = 1.2348, sigma_2 = 0.9095
# Run 8: Mean bootstrap Var(D) = 0.06717078332430527 (High bound: 0.5717440412022018)
# Run 9: N = 328, M = 24, mu_X = -0.2345, sigma_X = 1.7738, mu_epsilon = 1.2136, sigma_1 = 1.5709, sigma_2 = 1.0455
# Run 9: Mean bootstrap Var(D) = 0.05203448005074425 (High bound: 0.14703103699258532)
# Run 10: N = 28, M = 2, mu_X = 5.5729, sigma_X = 0.7239, mu_epsilon = 3.2174, sigma_1 = 1.7732, sigma_2 = 1.0274
# Run 10: Mean bootstrap Var(D) = 0.3721976513280313 (High bound: 0.4322394981419588)
# Run 1: N = 14, M = 3, mu_X = -2.1852, sigma_X = 2.5777, mu_epsilon = -2.835, sigma_1 = 1.4427, sigma_2 = 1.012
# Run 1: Mean bootstrap Var(D) = 0.27595926534562404 (High bound: 2.243324124029438)
# Run 2: N = 28, M = 4, mu_X = 1.6229, sigma_X = 1.1328, mu_epsilon = -3.5649, sigma_1 = 0.6992, sigma_2 = 0.0442
# Run 2: Mean bootstrap Var(D) = 0.03976138807018741 (High bound: 0.28607051872975436)
# Run 3: N = 19, M = 7, mu_X = 4.8892, sigma_X = 2.8914, mu_epsilon = -7.245, sigma_1 = 0.6462, sigma_2 = 0.1539
# Run 3: Mean bootstrap Var(D) = 0.0072815202293511 (High bound: 1.2943964685337948)
# Run 4: N = 659, M = 170, mu_X = -1.0525, sigma_X = 0.7068, mu_epsilon = -1.7818, sigma_1 = 0.5779, sigma_2 = 0.1316
# Run 4: Mean bootstrap Var(D) = 0.0005225187637145592 (High bound: 0.003630622299833271)
# Run 5: N = 112, M = 68, mu_X = -4.3136, sigma_X = 1.2474, mu_epsilon = -2.4177, sigma_1 = 1.6297, sigma_2 = 0.5157
# Run 5: Mean bootstrap Var(D) = 0.004569955974004072 (High bound: 0.03836094805665583)
# Run 6: N = 76, M = 45, mu_X = -0.4206, sigma_X = 1.9707, mu_epsilon = -1.7792, sigma_1 = 0.8809, sigma_2 = 0.5798
# Run 6: Mean bootstrap Var(D) = 0.0025030722845568263 (High bound: 0.1302959984163386)
# Run 7: N = 148, M = 13, mu_X = 6.3859, sigma_X = 1.7107, mu_epsilon = -5.6064, sigma_1 = 1.138, sigma_2 = 0.5018
# Run 7: Mean bootstrap Var(D) = 0.043282158832397326 (High bound: 0.20875205946397135)
# Run 8: N = 380, M = 81, mu_X = 6.5845, sigma_X = 0.8338, mu_epsilon = -3.7867, sigma_1 = 0.683, sigma_2 = 0.3411
# Run 8: Mean bootstrap Var(D) = 0.0018472835031977468 (High bound: 0.010589160525118147)
# Run 9: N = 47, M = 6, mu_X = -0.7143, sigma_X = 1.6737, mu_epsilon = 0.4069, sigma_1 = 0.8938, sigma_2 = 0.4634
# Run 9: Mean bootstrap Var(D) = 0.04748808996719958 (High bound: 0.4222673596397423)
# Run 10: N = 278, M = 102, mu_X = 4.463, sigma_X = 1.915, mu_epsilon = -2.3854, sigma_1 = 0.7577, sigma_2 = 0.649
# Run 10: Mean bootstrap Var(D) = 0.001453909437366665 (High bound: 0.04580712528473975)
# Run 1: N = 38, M = 16, mu_X = -0.5638, sigma_X = 0.9314, mu_epsilon = 2.9697, sigma_1 = 1.2115, sigma_2 = 0.3639
# Run 1: Mean bootstrap Var(D) = 0.015427608443311572 (High bound: 0.08119458168714425)
# Run 2: N = 576, M = 223, mu_X = -1.3106, sigma_X = 2.3827, mu_epsilon = -2.2347, sigma_1 = 2.6057, sigma_2 = 2.2298
# Run 2: Mean bootstrap Var(D) = 0.009525267941368864 (High bound: 0.040971749386864084)
# Run 3: N = 1366, M = 423, mu_X = 0.3461, sigma_X = 0.6759, mu_epsilon = -1.4593, sigma_1 = 0.5883, sigma_2 = 0.1584
# Run 3: Mean bootstrap Var(D) = 0.00019164933832007902 (High bound: 0.001426068640642858)
# Run 4: N = 547, M = 97, mu_X = -5.4655, sigma_X = 1.9691, mu_epsilon = -0.742, sigma_1 = 0.8771, sigma_2 = 0.7078
# Run 4: Mean bootstrap Var(D) = 0.0027644303472451185 (High bound: 0.041699022618557104)
# Run 5: N = 760, M = 340, mu_X = -2.175, sigma_X = 1.7819, mu_epsilon = 2.1107, sigma_1 = 1.27, sigma_2 = 0.8754
# Run 5: Mean bootstrap Var(D) = 0.00104905945068389 (High bound: 0.013816230854003643)
# Run 6: N = 84, M = 17, mu_X = -1.0853, sigma_X = 1.6441, mu_epsilon = 1.2452, sigma_1 = 1.2249, sigma_2 = 0.3515
# Run 6: Mean bootstrap Var(D) = 0.02709480155452193 (High bound: 0.17760204235762578)
# Run 7: N = 802, M = 375, mu_X = -1.331, sigma_X = 0.8139, mu_epsilon = -3.4372, sigma_1 = 1.0555, sigma_2 = 0.8759
# Run 7: Mean bootstrap Var(D) = 0.0007519818654508812 (High bound: 0.003029339319578995)
# Run 8: N = 40, M = 14, mu_X = 0.9349, sigma_X = 1.7763, mu_epsilon = -1.9963, sigma_1 = 1.1919, sigma_2 = 0.1954
# Run 8: Mean bootstrap Var(D) = 0.021486987952866344 (High bound: 0.2794478181998455)
# Run 9: N = 272, M = 12, mu_X = 1.5232, sigma_X = 2.8862, mu_epsilon = -0.9917, sigma_1 = 2.1479, sigma_2 = 0.6296
# Run 9: Mean bootstrap Var(D) = 0.15862415801402013 (High bound: 0.583489092069935)
# Run 10: N = 28, M = 17, mu_X = 2.093, sigma_X = 1.7764, mu_epsilon = 0.2692, sigma_1 = 0.9508, sigma_2 = 0.0512
# Run 10: Mean bootstrap Var(D) = 0.006756434917122323 (High bound: 0.2728009372454965)
# Run 1: N = 18, M = 12, mu_X = 0.5571, sigma_X = 1.2254, mu_epsilon = -1.4812, sigma_1 = 1.5489, sigma_2 = 1.5472
# Run 1: Mean bootstrap Var(D) = 0.033304292788393204 (High bound: 0.22279740074201382)
# Run 2: N = 327, M = 13, mu_X = -0.6722, sigma_X = 0.7622, mu_epsilon = 0.1554, sigma_1 = 1.2891, sigma_2 = 0.6836
# Run 2: Mean bootstrap Var(D) = 0.045873612671593955 (High bound: 0.06277903305927303)
# Run 3: N = 997, M = 344, mu_X = -2.9113, sigma_X = 2.3102, mu_epsilon = 5.5521, sigma_1 = 1.0849, sigma_2 = 0.8267
# Run 3: Mean bootstrap Var(D) = 0.0009153294053940495 (High bound: 0.01983286790850549)
# Run 4: N = 306, M = 92, mu_X = -5.6804, sigma_X = 2.041, mu_epsilon = 0.1514, sigma_1 = 1.0514, sigma_2 = 0.4767
# Run 4: Mean bootstrap Var(D) = 0.0030076910199929325 (High bound: 0.05443126842935739)
# Run 5: N = 62, M = 19, mu_X = -0.5027, sigma_X = 2.667, mu_epsilon = -6.5133, sigma_1 = 1.3212, sigma_2 = 0.3174
# Run 5: Mean bootstrap Var(D) = 0.01926847710232432 (High bound: 0.43147765016497586)
# Run 6: N = 54, M = 10, mu_X = -0.7291, sigma_X = 0.7066, mu_epsilon = 1.5896, sigma_1 = 1.1957, sigma_2 = 0.4967
# Run 6: Mean bootstrap Var(D) = 0.033822056941852335 (High bound: 0.07307393429290465)
# Run 7: N = 296, M = 134, mu_X = 0.3447, sigma_X = 1.3222, mu_epsilon = -7.6987, sigma_1 = 1.2607, sigma_2 = 0.3552
# Run 7: Mean bootstrap Var(D) = 0.0021852369209194047 (High bound: 0.01936350818456314)
# Run 8: N = 66, M = 24, mu_X = 1.0213, sigma_X = 2.4567, mu_epsilon = 0.8229, sigma_1 = 1.3215, sigma_2 = 0.5764
# Run 8: Mean bootstrap Var(D) = 0.016863929533224423 (High bound: 0.316193706269851)
# Run 9: N = 2905, M = 823, mu_X = 0.3305, sigma_X = 1.8897, mu_epsilon = 4.4412, sigma_1 = 0.9752, sigma_2 = 0.0848
# Run 9: Mean bootstrap Var(D) = 0.00026043891725427377 (High bound: 0.0050584537350938956)
# Run 10: N = 398, M = 171, mu_X = 1.5572, sigma_X = 1.687, mu_epsilon = 2.0681, sigma_1 = 1.3772, sigma_2 = 0.0516
# Run 10: Mean bootstrap Var(D) = 0.0021225945017904406 (High bound: 0.023494931464733505)
# Run 1: N = 367, M = 24, mu_X = -2.688, sigma_X = 1.659, mu_epsilon = 2.994, sigma_1 = 1.9011, sigma_2 = 1.3279
# Run 1: Mean bootstrap Var(D) = 0.07536343082977268 (High bound: 0.14754653863290906)
# Run 2: N = 2242, M = 710, mu_X = 1.5791, sigma_X = 2.0506, mu_epsilon = -3.6142, sigma_1 = 2.4271, sigma_2 = 1.6666
# Run 2: Mean bootstrap Var(D) = 0.002675575014730377 (High bound: 0.00917610485987548)
# Run 3: N = 306, M = 57, mu_X = 7.1177, sigma_X = 3.4115, mu_epsilon = -4.0914, sigma_1 = 1.3902, sigma_2 = 1.2665
# Run 3: Mean bootstrap Var(D) = 0.01458574690001254 (High bound: 0.21290172187797324)
# Run 4: N = 17, M = 4, mu_X = 2.0712, sigma_X = 1.5395, mu_epsilon = 4.3817, sigma_1 = 1.2131, sigma_2 = 0.5999
# Run 4: Mean bootstrap Var(D) = 0.11469660400372772 (High bound: 0.6768467734667399)
# Run 5: N = 16, M = 11, mu_X = 4.64, sigma_X = 2.2802, mu_epsilon = -0.3635, sigma_1 = 1.0158, sigma_2 = 0.2649
# Run 5: Mean bootstrap Var(D) = 0.008624077812284175 (High bound: 0.7041649504648728)
# Run 6: N = 141, M = 17, mu_X = -0.9196, sigma_X = 1.8811, mu_epsilon = 4.8211, sigma_1 = 1.6873, sigma_2 = 1.2409
# Run 6: Mean bootstrap Var(D) = 0.09375196401750473 (High bound: 0.25358612185199386)
# Run 7: N = 2563, M = 252, mu_X = 1.9802, sigma_X = 3.2144, mu_epsilon = 1.4737, sigma_1 = 1.0097, sigma_2 = 0.36
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-b779daad52f4> in <module>()
#       4
#       5 while True:
# ----> 6     variances, bounds, diffs = calculate_var_and_bound(10)
#       7     improvement_bootstrap_vars = improvement_bootstrap_vars + variances
#       8     improvement_theoretical_var_bounds = improvement_theoretical_var_bounds + bounds
#
# <ipython-input-2-9157066f4fc2> in calculate_var_and_bound(runs)
#      46         improvement_theoretical_var_bound = (
#      47             var_V(sigma_sq_X, sigma_sq_1, N, M) +
# ---> 48             var_V(sigma_sq_X, sigma_sq_2, N, M)
#      49         )
#      50         rel_difference = improvement_bootstrap_var / improvement_theoretical_var_bound
#
# ~/value_of_experimentation/src/normal_normal_model.py in var_V(sigma_sq_X, sigma_sq_eps, N, M)
#      49         acc += var_XIr(r, sigma_sq_X, sigma_sq_eps, N)
#      50         for s in range(r+1, N+1, 1):
# ---> 51             acc += 2 * cov_XIr_XIs(r, s, sigma_sq_X, sigma_sq_eps, N)
#      52
#      53     return acc / M**2
#
# ~/value_of_experimentation/src/normal_normal_model.py in cov_XIr_XIs(r, s, sigma_sq_X, sigma_sq_eps, N, **kwargs)
#      40         (r_act * (N-s_act+1)) /
#      41         ((N+1) ** 2 * (N+2)) /
# ---> 42         norm.pdf(norm.ppf(r_act/(N+1))) /
#      43         norm.pdf(norm.ppf(s_act/(N+1)))
#      44     )
#
# ~/anaconda/envs/expt_dashboard/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py in ppf(self, q, *args, **kwds)
#    1909         """
#    1910         args, loc, scale = self._parse_args(*args, **kwds)
# -> 1911         q, loc, scale = map(asarray, (q, loc, scale))
#    1912         args = tuple(map(asarray, args))
#    1913         cond0 = self._argcheck(*args) & (scale > 0) & (loc == loc)
#
# KeyboardInterrupt:

# %%
plt.clf()
plt.figure(figsize=(4, 2))
plt.hist(rel_differences, bins=20)
plt.xlim(0.00, 1.01)
plt.xlabel('Empirical variance / Theoretical bound')
plt.ylabel('Count')
# plt.show()
plt.savefig('../output/ratio_empirical_bound_distribution.pdf',
            bbox_inches='tight')
